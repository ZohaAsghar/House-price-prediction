# %% [markdown]
# <a href="https://colab.research.google.com/github/ZohaAsghar/House-price-prediction/blob/main/covid_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/covid_19.csv")

# %%
df
# Out:
#               country      continent   population         day  \
# 0        Saint-Helena         Africa       6115.0  2024-06-30
# 1    Falkland-Islands  South-America       3539.0  2024-06-30
# 2          Montserrat  North-America       4965.0  2024-06-30
# 3    Diamond-Princess            NaN          NaN  2024-06-30
# 4        Vatican-City         Europe        799.0  2024-06-30
# ..                ...            ...          ...         ...
# 233         Argentina  South-America   46010234.0  2024-06-30
# 234       Netherlands         Europe   17211447.0  2024-06-30
# 235            Mexico  North-America  131562772.0  2024-06-30
# 236              Iran           Asia   86022837.0  2024-06-30
# 237         Indonesia           Asia  279134505.0  2024-06-30
#
#                           time     Cases  Recovered    Deaths        Tests
# 0    2024-06-30T16:15:16+00:00      2166        2.0       NaN          NaN
# ...

# %%
df.describe()
# Out:
#          population         Cases     Recovered        Deaths         Tests
# count  2.290000e+02  2.380000e+02  1.900000e+02  2.330000e+02  2.130000e+02
# mean   3.469404e+07  8.883449e+06  1.006214e+07  9.026621e+04  3.298829e+07
# std    1.386374e+08  5.193031e+07  5.555519e+07  5.163434e+05  1.198779e+08
# min    7.990000e+02  9.000000e+00  2.000000e+00  1.000000e+00  7.850000e+03
# 25%    4.454310e+05  2.741875e+04  2.197250e+04  2.250000e+02  3.478150e+05
# 50%    5.797805e+06  2.320425e+05  2.351455e+05  2.570000e+03  2.226216e+06
# 75%    2.210284e+07  1.565481e+06  2.078212e+06  1.805700e+04  1.346373e+07
# max    1.448471e+09  7.047539e+08  6.756198e+08  7.010681e+06  1.186852e+09

# %%
df.head()
# Out:
#             country      continent  population         day  \
# 0      Saint-Helena         Africa      6115.0  2024-06-30
# 1  Falkland-Islands  South-America      3539.0  2024-06-30
# 2        Montserrat  North-America      4965.0  2024-06-30
# 3  Diamond-Princess            NaN         NaN  2024-06-30
# 4      Vatican-City         Europe       799.0  2024-06-30
#
#                         time  Cases  Recovered  Deaths    Tests
# 0  2024-06-30T16:15:16+00:00   2166        2.0     NaN      NaN
# 1  2024-06-30T16:15:16+00:00   1930     1930.0     NaN   8632.0
# 2  2024-06-30T16:15:16+00:00   1403     1376.0     8.0  17762.0
# 3  2024-06-30T16:15:16+00:00    712      699.0    13.0      NaN
# 4  2024-06-30T16:15:16+00:00     29       29.0     NaN      NaN

# %%
df.tail()
# Out:
#          country      continent   population         day  \
# 233    Argentina  South-America   46010234.0  2024-06-30
# 234  Netherlands         Europe   17211447.0  2024-06-30
# 235       Mexico  North-America  131562772.0  2024-06-30
# 236         Iran           Asia   86022837.0  2024-06-30
# 237    Indonesia           Asia  279134505.0  2024-06-30
#
#                           time     Cases  Recovered    Deaths        Tests
# 233  2024-06-30T16:15:10+00:00  10128845  9997258.0  130841.0   35716069.0
# 234  2024-06-30T16:15:10+00:00   8635786  8612599.0   22992.0   25984435.0
# 235  2024-06-30T16:15:10+00:00   7702809  6899865.0  334958.0   20013810.0
# 236  2024-06-30T16:15:10+00:00   7627186        NaN  146811.0   57320267.0
# 237  2024-06-30T16:15:10+00:00   6829221  6647104.0  162063.0  114158919.0

# %%
df.count()
# Out:
# country       238
# continent     236
# population    229
# day           238
# time          238
# Cases         238
# Recovered     190
# Deaths        233
# Tests         213
# dtype: int64

# %%
df.value_counts()
# Out:
# country              continent      population  day         time                       Cases     Recovered   Deaths   Tests
# Afghanistan          Asia           40754388.0  2024-06-30  2024-06-30T16:15:12+00:00  234174    211080.0    7996.0   1390730.0     1
# Albania              Europe         2866374.0   2024-06-30  2024-06-30T16:15:12+00:00  334863    330233.0    3605.0   1941032.0     1
# Algeria              Africa         45350148.0  2024-06-30  2024-06-30T16:15:12+00:00  272010    183061.0    6881.0   230960.0      1
# Angola               Africa         35027343.0  2024-06-30  2024-06-30T16:15:13+00:00  107327    103419.0    1937.0   1499795.0     1
# Antigua-and-Barbuda  North-America  99509.0     2024-06-30  2024-06-30T16:15:15+00:00  9106      8954.0      146.0    18901.0       1
#                                                                                                                                    ..
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     238 non-null    object
#  1   continent   236 non-null    object
#  2   population  229 non-null    float64
#  3   day         238 non-null    object
#  4   time        238 non-null    object
#  5   Cases       238 non-null    int64
#  6   Recovered   190 non-null    float64
#  7   Deaths      233 non-null    float64
#  8   Tests       213 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 16.9+ KB

# %%
df["country"].value_counts()
# Out:
# country
# Saint-Helena        1
# Falkland-Islands    1
# Montserrat          1
# Diamond-Princess    1
# Vatican-City        1
#                    ..
# Argentina           1
# Netherlands         1
# Mexico              1
# Iran                1
# Indonesia           1
# Name: count, Length: 238, dtype: int64

# %%
df.isnull()
# Out:
#      country  continent  population    day   time  Cases  Recovered  Deaths  \
# 0      False      False       False  False  False  False      False    True
# 1      False      False       False  False  False  False      False    True
# 2      False      False       False  False  False  False      False   False
# 3      False       True        True  False  False  False      False   False
# 4      False      False       False  False  False  False      False    True
# ..       ...        ...         ...    ...    ...    ...        ...     ...
# 233    False      False       False  False  False  False      False   False
# 234    False      False       False  False  False  False      False   False
# 235    False      False       False  False  False  False      False   False
# 236    False      False       False  False  False  False       True   False
# 237    False      False       False  False  False  False      False   False
#
#      Tests
# 0     True
# 1    False
# 2    False
# ...

# %%
df["country"].value_counts()
# Out:
# country
# Saint-Helena        1
# Falkland-Islands    1
# Montserrat          1
# Diamond-Princess    1
# Vatican-City        1
#                    ..
# Argentina           1
# Netherlands         1
# Mexico              1
# Iran                1
# Indonesia           1
# Name: count, Length: 238, dtype: int64

# %%
df["continent"].value_counts()
# Out:
# continent
# Africa           59
# Asia             51
# Europe           49
# North-America    40
# Oceania          21
# South-America    15
# All               1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
coder=LabelEncoder()

# %%
df["continent"]=df["continent"].astype(str)
df["continent"]=coder.fit_transform(df["continent"])

# %%
df
# Out:
#               country  continent   population         day  \
# 0        Saint-Helena          0       6115.0  2024-06-30
# 1    Falkland-Islands          6       3539.0  2024-06-30
# 2          Montserrat          4       4965.0  2024-06-30
# 3    Diamond-Princess          7          NaN  2024-06-30
# 4        Vatican-City          3        799.0  2024-06-30
# ..                ...        ...          ...         ...
# 233         Argentina          6   46010234.0  2024-06-30
# 234       Netherlands          3   17211447.0  2024-06-30
# 235            Mexico          4  131562772.0  2024-06-30
# 236              Iran          2   86022837.0  2024-06-30
# 237         Indonesia          2  279134505.0  2024-06-30
#
#                           time     Cases  Recovered    Deaths        Tests
# 0    2024-06-30T16:15:16+00:00      2166        2.0       NaN          NaN
# 1    2024-06-30T16:15:16+00:00      1930     1930.0       NaN       8632.0
# ...

# %%
df["country"]=df["country"].astype(str)
df["country"]=coder.fit_transform(df["country"])

# %%
df
# Out:
#      country  continent   population         day                       time  \
# 0        178          0       6115.0  2024-06-30  2024-06-30T16:15:16+00:00
# 1         73          6       3539.0  2024-06-30  2024-06-30T16:15:16+00:00
# 2        143          4       4965.0  2024-06-30  2024-06-30T16:15:16+00:00
# 3         59          7          NaN  2024-06-30  2024-06-30T16:15:16+00:00
# 4        230          3        799.0  2024-06-30  2024-06-30T16:15:16+00:00
# ..       ...        ...          ...         ...                        ...
# 233        9          6   46010234.0  2024-06-30  2024-06-30T16:15:10+00:00
# 234      150          3   17211447.0  2024-06-30  2024-06-30T16:15:10+00:00
# 235      137          4  131562772.0  2024-06-30  2024-06-30T16:15:10+00:00
# 236      100          2   86022837.0  2024-06-30  2024-06-30T16:15:10+00:00
# 237       99          2  279134505.0  2024-06-30  2024-06-30T16:15:10+00:00
#
#         Cases  Recovered    Deaths        Tests
# ...

# %%
df["day"]=df["day"].astype(str)
df["day"]=coder.fit_transform(df["day"])

# %%
df
# Out:
#      country  continent   population  day                       time  \
# 0        178          0       6115.0    0  2024-06-30T16:15:16+00:00
# 1         73          6       3539.0    0  2024-06-30T16:15:16+00:00
# 2        143          4       4965.0    0  2024-06-30T16:15:16+00:00
# 3         59          7          NaN    0  2024-06-30T16:15:16+00:00
# 4        230          3        799.0    0  2024-06-30T16:15:16+00:00
# ..       ...        ...          ...  ...                        ...
# 233        9          6   46010234.0    0  2024-06-30T16:15:10+00:00
# 234      150          3   17211447.0    0  2024-06-30T16:15:10+00:00
# 235      137          4  131562772.0    0  2024-06-30T16:15:10+00:00
# 236      100          2   86022837.0    0  2024-06-30T16:15:10+00:00
# 237       99          2  279134505.0    0  2024-06-30T16:15:10+00:00
#
#         Cases  Recovered    Deaths        Tests
# 0        2166        2.0       NaN          NaN
# ...

# %%
df["population"]=df["population"].astype(str)
df["population"]=coder.fit_transform(df["population"])

# %%
df
# Out:
#      country  continent  population  day                       time     Cases  \
# 0        178          0         181    0  2024-06-30T16:15:16+00:00      2166
# 1         73          6         122    0  2024-06-30T16:15:16+00:00      1930
# 2        143          4         155    0  2024-06-30T16:15:16+00:00      1403
# 3         59          7         229    0  2024-06-30T16:15:16+00:00       712
# 4        230          3         206    0  2024-06-30T16:15:16+00:00        29
# ..       ...        ...         ...  ...                        ...       ...
# 233        9          6         149    0  2024-06-30T16:15:10+00:00  10128845
# 234      150          3          52    0  2024-06-30T16:15:10+00:00   8635786
# 235      137          4          34    0  2024-06-30T16:15:10+00:00   7702809
# 236      100          2         211    0  2024-06-30T16:15:10+00:00   7627186
# 237       99          2          93    0  2024-06-30T16:15:10+00:00   6829221
#
# ...

# %%
df["time"]=df["time"].astype(str)
df["time"]=coder.fit_transform(df["time"])

# %%
df
# Out:
#      country  continent  population  day  time     Cases  Recovered    Deaths  \
# 0        178          0         181    0     6      2166        2.0       NaN
# 1         73          6         122    0     6      1930     1930.0       NaN
# 2        143          4         155    0     6      1403     1376.0       8.0
# 3         59          7         229    0     6       712      699.0      13.0
# 4        230          3         206    0     6        29       29.0       NaN
# ..       ...        ...         ...  ...   ...       ...        ...       ...
# 233        9          6         149    0     0  10128845  9997258.0  130841.0
# 234      150          3          52    0     0   8635786  8612599.0   22992.0
# 235      137          4          34    0     0   7702809  6899865.0  334958.0
# 236      100          2         211    0     0   7627186        NaN  146811.0
# 237       99          2          93    0     0   6829221  6647104.0  162063.0
#
#            Tests
# ...

# %%
df["Cases"]=df["Cases"].astype(str)
df["Cases"]=coder.fit_transform(df["Cases"])

# %%
df
# Out:
#      country  continent  population  day  time  Cases  Recovered    Deaths  \
# 0        178          0         181    0     6     80        2.0       NaN
# 1         73          6         122    0     6     71     1930.0       NaN
# 2        143          4         155    0     6     42     1376.0       8.0
# 3         59          7         229    0     6    205      699.0      13.0
# 4        230          3         206    0     6    108       29.0       NaN
# ..       ...        ...         ...  ...   ...    ...        ...       ...
# 233        9          6         149    0     0      3  9997258.0  130841.0
# 234      150          3          52    0     0    224  8612599.0   22992.0
# 235      137          4          34    0     0    214  6899865.0  334958.0
# 236      100          2         211    0     0    212        NaN  146811.0
# 237       99          2          93    0     0    200  6647104.0  162063.0
#
#            Tests
# 0            NaN
# 1         8632.0
# ...

# %%
df["Deaths"]=df["Deaths"].astype(str)
df["Deaths"]=coder.fit_transform(df["Deaths"])

# %%
df
# Out:
#      country  continent  population  day  time  Cases  Recovered  Deaths  \
# 0        178          0         181    0     6     80        2.0     218
# 1         73          6         122    0     6     71     1930.0     218
# 2        143          4         155    0     6     42     1376.0     198
# 3         59          7         229    0     6    205      699.0      28
# 4        230          3         206    0     6    108       29.0     218
# ..       ...        ...         ...  ...   ...    ...        ...     ...
# 233        9          6         149    0     0      3  9997258.0      30
# 234      150          3          52    0     0    224  8612599.0      95
# 235      137          4          34    0     0    214  6899865.0     128
# 236      100          2         211    0     0    212        NaN      46
# 237       99          2          93    0     0    200  6647104.0      52
#
#            Tests
# 0            NaN
# 1         8632.0
# 2        17762.0
# 3            NaN
# ...

# %%
df["Recovered"]=df["Recovered"].astype(str)
df["Recovered"]=coder.fit_transform(df["Recovered"])

# %%
df
# Out:
#      country  continent  population  day  time  Cases  Recovered  Deaths  \
# 0        178          0         181    0     6     80         63     218
# 1         73          6         122    0     6     71         60     218
# 2        143          4         155    0     6     42         33     198
# 3         59          7         229    0     6    205        166      28
# 4        230          3         206    0     6    108         89     218
# ..       ...        ...         ...  ...   ...    ...        ...     ...
# 233        9          6         149    0     0      3        189      30
# 234      150          3          52    0     0    224        176      95
# 235      137          4          34    0     0    214        165     128
# 236      100          2         211    0     0    212        190      46
# 237       99          2          93    0     0    200        156      52
#
#            Tests
# 0            NaN
# 1         8632.0
# 2        17762.0
# 3            NaN
# ...

# %%
df["Tests"]=df["Tests"].astype(str)
df["Tests"]=coder.fit_transform(df["Tests"])

# %%
df
# Out:
#      country  continent  population  day  time  Cases  Recovered  Deaths  \
# 0        178          0         181    0     6     80         63     218
# 1         73          6         122    0     6     71         60     218
# 2        143          4         155    0     6     42         33     198
# 3         59          7         229    0     6    205        166      28
# 4        230          3         206    0     6    108         89     218
# ..       ...        ...         ...  ...   ...    ...        ...     ...
# 233        9          6         149    0     0      3        189      30
# 234      150          3          52    0     0    224        176      95
# 235      137          4          34    0     0    214        165     128
# 236      100          2         211    0     0    212        190      46
# 237       99          2          93    0     0    200        156      52
#
#      Tests
# 0      212
# 1      206
# 2       56
# 3      212
# 4      212
# ..     ...
# ...

# %%
x=(df.drop(["Cases"],axis=1))
y=df["Cases"]

# %%
x
# Out:
#      country  continent  population  day  time  Recovered  Deaths  Tests
# 0        178          0         181    0     6         63     218    212
# 1         73          6         122    0     6         60     218    206
# 2        143          4         155    0     6         33     198     56
# 3         59          7         229    0     6        166      28    212
# 4        230          3         206    0     6         89     218    212
# ..       ...        ...         ...  ...   ...        ...     ...    ...
# 233        9          6         149    0     0        189      30    128
# 234      150          3          52    0     0        176      95     99
# 235      137          4          34    0     0        165     128     70
# 236      100          2         211    0     0        190      46    165
# 237       99          2          93    0     0        156      52     13
#
# [238 rows x 8 columns]

# %%
y
# Out:
# 0       80
# 1       71
# 2       42
# 3      205
# 4      108
#       ...
# 233      3
# 234    224
# 235    214
# 236    212
# 237    200
# Name: Cases, Length: 238, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["Recovered"],df["Deaths"])
plt.xlabel("Recovered")
plt.ylabel("Deaths")
plt.title("Recovered vs Deaths")
plt.show()

# %%
plt.plot(df["Recovered"],df["Deaths"])
plt.xlabel("Recovered")
plt.ylabel("Deaths")
plt.title("Recovered vs Deaths")
plt.show()

# %%
plt.bar(df["Recovered"],df["Deaths"])
plt.xlabel("Recovered")
plt.ylabel("Deaths")
plt.title("Recovered vs Deaths")
plt.show()

# %%
plt.eventplot(df["Deaths"])

# %%
plt.hist(df["Deaths"])
# Out:
# (array([25., 23., 24., 25., 22., 23., 23., 22., 23., 28.]),
#  array([  0. ,  21.8,  43.6,  65.4,  87.2, 109. , 130.8, 152.6, 174.4,
#         196.2, 218. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **SeaBorn**

# %%
import seaborn as seb

# %%
seb.scatterplot(x=df["Recovered"],y=df["Deaths"])
plt.xlabel("Recovered")
plt.ylabel("Deaths")
plt.title("Recovered vs Deaths")
plt.show()

# %%
seb.lineplot(x=df["Recovered"],y=df["Deaths"])
plt.xlabel("Recovered")
plt.ylabel("Deaths")
plt.title("Recovered vs Deaths")
plt.show()

# %%
seb.barplot(x=df["Recovered"],y=df["Deaths"])
plt.xlabel("Recovered")
plt.ylabel("Deaths")
plt.title("Recovered vs Deaths")
plt.show()

# %%
seb.boxplot(x=df["Recovered"],y=df["Deaths"])
plt.xlabel("Recovered")
plt.ylabel("Deaths")
plt.title("Recovered vs Deaths")
plt.show()

# %%
seb.violinplot(x=df["Recovered"],y=df["Deaths"])
plt.xlabel("Recovered")
plt.ylabel("Deaths")
plt.title("Recovered vs Deaths")
plt.show()

# %%
seb.histplot(x=df["Recovered"],y=df["Deaths"])
plt.xlabel("Recovered")
plt.ylabel("Deaths")
plt.title("Recovered vs Deaths")
plt.show()

# %%
seb.kdeplot(x=df["Recovered"],y=df["Deaths"])
plt.xlabel("Recovered")
plt.ylabel("Deaths")
plt.title("Recovered vs Deaths")
plt.show()

# %%
seb.pairplot(df, x_vars=["Recovered"] ,y_vars=["Deaths"])
plt.xlabel("Recovered")
plt.ylabel("Deaths")
plt.title("Recovered vs Deaths")
plt.show()

# %%
x=df.drop(["Cases"],axis=1)
y=df["Cases"]

# %%
x
# Out:
#      country  continent  population  day  time  Recovered  Deaths  Tests
# 0        178          0         181    0     6         63     218    212
# 1         73          6         122    0     6         60     218    206
# 2        143          4         155    0     6         33     198     56
# 3         59          7         229    0     6        166      28    212
# 4        230          3         206    0     6         89     218    212
# ..       ...        ...         ...  ...   ...        ...     ...    ...
# 233        9          6         149    0     0        189      30    128
# 234      150          3          52    0     0        176      95     99
# 235      137          4          34    0     0        165     128     70
# 236      100          2         211    0     0        190      46    165
# 237       99          2          93    0     0        156      52     13
#
# [238 rows x 8 columns]

# %%
y
# Out:
# 0       80
# 1       71
# 2       42
# 3      205
# 4      108
#       ...
# 233      3
# 234    224
# 235    214
# 236    212
# 237    200
# Name: Cases, Length: 238, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 190 entries, 32 to 129
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     190 non-null    int64
#  1   continent   190 non-null    int64
#  2   population  190 non-null    int64
#  3   day         190 non-null    int64
#  4   time        190 non-null    int64
#  5   Recovered   190 non-null    int64
#  6   Deaths      190 non-null    int64
#  7   Tests       190 non-null    int64
# dtypes: int64(8)
# memory usage: 13.4 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, 75 to 131
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     48 non-null     int64
#  1   continent   48 non-null     int64
#  2   population  48 non-null     int64
#  3   day         48 non-null     int64
#  4   time        48 non-null     int64
#  5   Recovered   48 non-null     int64
#  6   Deaths      48 non-null     int64
#  7   Tests       48 non-null     int64
# dtypes: int64(8)
# memory usage: 3.4 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 190 entries, 32 to 129
# Series name: Cases
# Non-Null Count  Dtype
# --------------  -----
# 190 non-null    int64
# dtypes: int64(1)
# memory usage: 3.0 KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 48 entries, 75 to 131
# Series name: Cases
# Non-Null Count  Dtype
# --------------  -----
# 48 non-null     int64
# dtypes: int64(1)
# memory usage: 768.0 bytes

# %%
from sklearn.linear_model import LinearRegression

# %%
modle=LinearRegression()

# %%
modle.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=modle.predict(x_test)
pred
# Out:
# array([187.39572834, 173.72898508,  94.84822528, 179.90047277,
#        125.35127172, 100.7610644 , 180.42964121, 178.32781171,
#         52.15331542,  66.30667689,  86.47514713, 149.85835325,
#        175.1698826 , 185.49505189,  58.81739296, 178.24269122,
#         98.14764858, 169.13048758, 157.98070092, 156.52870727,
#         78.99692663, 114.3703481 , 163.80475581,  77.92935838,
#        178.32047153, 160.78771621, 122.61636775, 136.54303261,
#        179.6553454 , 173.8952321 , 117.30153728,  44.38424673,
#         45.35286738,  35.46783772, 164.32895128,  32.5479701 ,
#         70.7668922 ,  56.55989857, 178.39507452, 142.99940669,
#        181.13261765, 142.04093721, 121.74038409, 182.45939393,
#         56.22820764,  87.58373675, 141.11349223, 167.9435579 ])

# %%
accuracy=modle.score(x_test,y_test)
accuracy
# Out:
# 0.2945009255358272

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
modle=DecisionTreeRegressor()

# %%
modle.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
modle.predict(x_test)
# Out:
# array([ 55., 137.,  84., 193., 150., 113.,  55., 224.,  34.,  54.,  70.,
#        192.,   1., 131.,  42., 193., 107.,  85., 228., 190.,  70., 125.,
#        207.,  66., 194., 201., 135., 156.,  27., 223., 150.,  28.,  14.,
#         57., 207.,  12.,  58., 104., 124., 174., 222., 168., 150.,  81.,
#         39.,  91., 190., 207.])

# %%
accuracy=modle.score(x_test,y_test)
accuracy
# Out:
# 0.15401978210363798
